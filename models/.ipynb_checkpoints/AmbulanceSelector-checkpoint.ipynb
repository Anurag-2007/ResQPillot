# %%
import torch
import numpy as np
import pandas as pd
import einops as eops
import torch.nn as nn

# %%
import kagglehub
import pathlib
from torch.utils.data import TensorDataset, DataLoader

# %%
path = kagglehub.dataset_download("emirhanakku/synthetic-medical-triage-priority-dataset")
path
# Out:
# 'C:\\Users\\ayush\\.cache\\kagglehub\\datasets\\emirhanakku\\synthetic-medical-triage-priority-dataset\\versions\\1'

# %%
path = path.split('\\')[-2]

# %%
files = pathlib.Path(path).glob("*.csv")

# %%
dataset = list(files)[0]
dataset
# Out:
# WindowsPath('versions/synthetic_medical_triage.csv')

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#         age  heart_rate  systolic_blood_pressure  oxygen_saturation  \
# 0      17.9        95.4                    147.1               97.4
# 1      79.2       147.9                    158.6               96.0
# 2      51.1        87.1                    128.2               98.5
# 3      56.8        84.7                    147.2               92.5
# 4      39.2        58.0                    107.8               99.0
# ...     ...         ...                      ...                ...
# 17995  52.8       100.1                    145.0               95.4
# 17996  37.1        84.8                    128.0               98.0
# 17997  59.2        64.9                    103.1               93.9
# 17998  70.4        90.6                    144.1               96.1
# 17999  74.1        85.8                    131.3               96.0
#
#        body_temperature  pain_level  chronic_disease_count  \
# 0                 36.48           1                      0
# 1                 39.35          10                      4
# 2                 37.74           5                      2
# 3                 37.55           4                      4
# 4                 36.26           2                      1
# ...                 ...         ...                    ...
# 17995             37.82           4                      2
# 17996             37.04           3                      3
# 17997             36.55           5                      1
# 17998             38.08           3                      4
# 17999             37.75           5                      2
#
#        previous_er_visits arrival_mode  triage_level
# 0                       0      walk_in             0
# 1                       2    ambulance             3
# 2                       2      walk_in             1
# 3                       4      walk_in             1
# 4                       1      walk_in             0
# ...                   ...          ...           ...
# 17995                   1      walk_in             1
# 17996                   3    ambulance             1
# 17997                   0      walk_in             1
# 17998                   3    ambulance             0
# 17999                   1      walk_in             2
#
# [18000 rows x 10 columns]

# %%
OnehotCol = ['pain_level', 'arrival_mode', 'chronic_disease_count', 'previous_er_visits']
data = pd.get_dummies(data, columns=OnehotCol, dtype=int)

normCol = ['age', 'heart_rate', 'systolic_blood_pressure', 'oxygen_saturation', 'body_temperature']
for col in normCol:
    data[col] = (data[col] - data[col].mean())/ data[col].std()

# %%
yCol = ['triage_level']
df_y = data[yCol]
df_x = data.drop(yCol, axis = 1)

df_x, df_y
# Out:
# (            age  heart_rate  systolic_blood_pressure  oxygen_saturation  \
#  0     -1.403914    0.713711                 1.011374           0.394741
#  1      1.805332    3.808426                 1.622645          -0.025574
#  2      0.334210    0.224451                 0.006764           0.724990
#  3      0.632622    0.082978                 1.016690          -1.076363
#  4     -0.288793   -1.490905                -1.077576           0.875102
#  ...         ...         ...                      ...                ...
#  17995  0.423210    0.990761                 0.899751          -0.205709
#  17996 -0.398734    0.088873                -0.003866           0.574877
#  17997  0.758270   -1.084171                -1.327400          -0.656048
#  17998  1.344625    0.430765                 0.851912           0.004448
#  17999  1.538331    0.147820                 0.171542          -0.025574
#
#         body_temperature  pain_level_1  pain_level_2  pain_level_3  \
#  0             -0.813392             1             0             0
#  1              2.323294             0             0             0
#  2              0.563690             0             0             0
#  3              0.356034             0             0             0
#  4             -1.053835             0             1             0
#  ...                 ...           ...           ...           ...
#  17995          0.651123             0             0             0
#  17996         -0.201356             0             0             1
#  17997         -0.736887             0             0             0
#  17998          0.935283             0             0             1
#  17999          0.574619             0             0             0
#
#         pain_level_4  pain_level_5  ...  previous_er_visits_2  \
#  0                 0             0  ...                     0
#  1                 0             0  ...                     1
#  2                 0             1  ...                     1
#  3                 1             0  ...                     0
#  4                 0             0  ...                     0
#  ...             ...           ...  ...                   ...
#  17995             1             0  ...                     0
#  17996             0             0  ...                     0
#  17997             0             1  ...                     0
#  17998             0             0  ...                     0
#  17999             0             1  ...                     0
#
#         previous_er_visits_3  previous_er_visits_4  previous_er_visits_5  \
#  0                         0                     0                     0
#  1                         0                     0                     0
#  2                         0                     0                     0
#  3                         0                     1                     0
#  4                         0                     0                     0
#  ...                     ...                   ...                   ...
#  17995                     0                     0                     0
#  17996                     1                     0                     0
#  17997                     0                     0                     0
#  17998                     1                     0                     0
#  17999                     0                     0                     0
#
#         previous_er_visits_6  previous_er_visits_7  previous_er_visits_8  \
#  0                         0                     0                     0
#  1                         0                     0                     0
#  2                         0                     0                     0
#  3                         0                     0                     0
#  4                         0                     0                     0
#  ...                     ...                   ...                   ...
#  17995                     0                     0                     0
#  17996                     0                     0                     0
#  17997                     0                     0                     0
#  17998                     0                     0                     0
#  17999                     0                     0                     0
#
#         previous_er_visits_9  previous_er_visits_10  previous_er_visits_11
#  0                         0                      0                      0
#  1                         0                      0                      0
#  2                         0                      0                      0
#  3                         0                      0                      0
#  4                         0                      0                      0
#  ...                     ...                    ...                    ...
#  17995                     0                      0                      0
#  17996                     0                      0                      0
#  17997                     0                      0                      0
#  17998                     0                      0                      0
#  17999                     0                      0                      0
#
#  [18000 rows x 41 columns],
#         triage_level
#  0                 0
#  1                 3
#  2                 1
#  3                 1
#  4                 0
#  ...             ...
#  17995             1
#  17996             1
#  17997             1
#  17998             0
#  17999             2
#
#  [18000 rows x 1 columns])

# %%
np_x = df_x.to_numpy()
np_y = df_y.to_numpy()

# %%
class AmbSelModel(nn.Module):
    def __init__(self, _nf :int):
        super(AmbSelModel, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(_nf, 64),
            nn.ReLU(),
            nn.Linear(64, 256),
            nn.Dropout(p=0.25),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, 4)
        )

    def forward(self, inp):
        return self.model(inp)

# %%
class Train():
    def __init__(self, _nFeature :int):
        self.model = AmbSelModel(_nFeature)
        self.loss = nn.CrossEntropyLoss()
        self.optim = torch.optim.Adam(self.model.parameters(), lr=0.01)
        self.histX = []
        self.histY = []

    def train(self, X :np.ndarray, Y :np.ndarray, epochs:int=100, _nbatch:int=32):
        print("Training starts")
        model = self.model
        optim = self.optim
        loss_fn = self.loss
        
        X = torch.from_numpy(X).float()
        Y = torch.from_numpy(Y).long().squeeze()
        print(Y)

        inp = TensorDataset(X, Y)
        data_loader = DataLoader(inp, batch_size=_nbatch, shuffle=True)
            
        for epoch in range(epochs):
            model.train()
            self.histY.append(epoch)

            avg_loss = 0

            for i, (train_X, train_Y) in enumerate(data_loader):
                optim.zero_grad()
                pred = model(train_X)
                class_loss = loss_fn(pred, train_Y)
                class_loss.backward()
                optim.step()
                avg_loss += class_loss.mean()
                
            epoch_loss = avg_loss / len(data_loader)
            self.histX.append(epoch_loss.item())
            print(f"Epoch {epoch}: Average Loss = {epoch_loss:.4f}")

#simple softmax between triage-level
    def pred(self, inp :np.ndarray, k :int=3):
        with torch.no_grad():
            inp = torch.Tensor(inp)
            pred_score = torch.softmax(self.model(inp))
            idx = []
            print(pred_score)
            for i in range(len(pred_score)):
                arg = torch.argmax(pred_score[i])
                pred_score[i] = arg+1

            return pred_score

    def save(self, name :str):
        torch.save(self.model, name)

# %%
model = Train(np_x.shape[-1])
np_x.shape
# Out:
# (18000, 41)

# %%
model.train(np_x, np_y, epochs=256, _nbatch=64)
# Out:
# Training starts
# tensor([0, 3, 1,  ..., 1, 0, 2])
# Epoch 0: Average Loss = 0.1878
# Epoch 1: Average Loss = 0.1845
# Epoch 2: Average Loss = 0.1839
# Epoch 3: Average Loss = 0.1821
# Epoch 4: Average Loss = 0.1807
# Epoch 5: Average Loss = 0.1796
# Epoch 6: Average Loss = 0.1779
# Epoch 7: Average Loss = 0.1802
# Epoch 8: Average Loss = 0.1768
# Epoch 9: Average Loss = 0.1778
# Epoch 10: Average Loss = 0.1703
# Epoch 11: Average Loss = 0.1734
# Epoch 12: Average Loss = 0.1697
# Epoch 13: Average Loss = 0.1756
# Epoch 14: Average Loss = 0.1717
# Epoch 15: Average Loss = 0.1681
# Epoch 16: Average Loss = 0.1698
# Epoch 17: Average Loss = 0.1667
# Epoch 18: Average Loss = 0.1677
# Epoch 19: Average Loss = 0.1696
# Epoch 20: Average Loss = 0.1670
# Epoch 21: Average Loss = 0.1639
# Epoch 22: Average Loss = 0.1639
# Epoch 23: Average Loss = 0.1620
# Epoch 24: Average Loss = 0.1637
# Epoch 25: Average Loss = 0.1576
# Epoch 26: Average Loss = 0.1604
# Epoch 27: Average Loss = 0.1549
# Epoch 28: Average Loss = 0.1566
# Epoch 29: Average Loss = 0.1582
# Epoch 30: Average Loss = 0.1535
# Epoch 31: Average Loss = 0.1528
# Epoch 32: Average Loss = 0.1515
# Epoch 33: Average Loss = 0.1662
# Epoch 34: Average Loss = 0.1526
# Epoch 35: Average Loss = 0.1530
# Epoch 36: Average Loss = 0.1538
# Epoch 37: Average Loss = 0.1552
# Epoch 38: Average Loss = 0.1541
# Epoch 39: Average Loss = 0.1518
# Epoch 40: Average Loss = 0.1518
# Epoch 41: Average Loss = 0.1448
# Epoch 42: Average Loss = 0.1509
# Epoch 43: Average Loss = 0.1486
# Epoch 44: Average Loss = 0.1489
# Epoch 45: Average Loss = 0.1468
# Epoch 46: Average Loss = 0.1519
# Epoch 47: Average Loss = 0.1486
# Epoch 48: Average Loss = 0.1452
# Epoch 49: Average Loss = 0.1484
# Epoch 50: Average Loss = 0.1432
# Epoch 51: Average Loss = 0.1475
# Epoch 52: Average Loss = 0.1454
# Epoch 53: Average Loss = 0.1427
# Epoch 54: Average Loss = 0.1403
# Epoch 55: Average Loss = 0.1419
# Epoch 56: Average Loss = 0.1439
# Epoch 57: Average Loss = 0.1418
# Epoch 58: Average Loss = 0.1459
# Epoch 59: Average Loss = 0.1418
# Epoch 60: Average Loss = 0.1339
# Epoch 61: Average Loss = 0.1335
# Epoch 62: Average Loss = 0.1418
# Epoch 63: Average Loss = 0.1431
# Epoch 64: Average Loss = 0.1472
# Epoch 65: Average Loss = 0.1459
# Epoch 66: Average Loss = 0.1355
# Epoch 67: Average Loss = 0.1332
# Epoch 68: Average Loss = 0.1336
# Epoch 69: Average Loss = 0.1377
# Epoch 70: Average Loss = 0.1347
# Epoch 71: Average Loss = 0.1514
# Epoch 72: Average Loss = 0.1440
# Epoch 73: Average Loss = 0.1399
# Epoch 74: Average Loss = 0.1395
# Epoch 75: Average Loss = 0.1356
# Epoch 76: Average Loss = 0.1331
# Epoch 77: Average Loss = 0.1363
# Epoch 78: Average Loss = 0.1340
# Epoch 79: Average Loss = 0.1313
# Epoch 80: Average Loss = 0.1338
# Epoch 81: Average Loss = 0.1384
# Epoch 82: Average Loss = 0.1396
# Epoch 83: Average Loss = 0.1376
# Epoch 84: Average Loss = 0.1313
# Epoch 85: Average Loss = 0.1321
# Epoch 86: Average Loss = 0.1366
# Epoch 87: Average Loss = 0.1297
# Epoch 88: Average Loss = 0.1643
# Epoch 89: Average Loss = 0.1427
# Epoch 90: Average Loss = 0.1349
# Epoch 91: Average Loss = 0.1387
# Epoch 92: Average Loss = 0.1399
# Epoch 93: Average Loss = 0.1311
# Epoch 94: Average Loss = 0.1325
# Epoch 95: Average Loss = 0.1307
# Epoch 96: Average Loss = 0.1245
# Epoch 97: Average Loss = 0.1338
# Epoch 98: Average Loss = 0.1296
# Epoch 99: Average Loss = 0.1341
# Epoch 100: Average Loss = 0.1443
# Epoch 101: Average Loss = 0.1400
# Epoch 102: Average Loss = 0.1423
# Epoch 103: Average Loss = 0.1342
# Epoch 104: Average Loss = 0.1284
# Epoch 105: Average Loss = 0.1272
# Epoch 106: Average Loss = 0.1274
# Epoch 107: Average Loss = 0.1283
# Epoch 108: Average Loss = 0.1294
# Epoch 109: Average Loss = 0.1274
# Epoch 110: Average Loss = 0.1255
# Epoch 111: Average Loss = 0.1257
# Epoch 112: Average Loss = 0.1246
# Epoch 113: Average Loss = 0.1277
# Epoch 114: Average Loss = 0.1330
# Epoch 115: Average Loss = 0.1224
# Epoch 116: Average Loss = 0.1269
# Epoch 117: Average Loss = 0.1174
# Epoch 118: Average Loss = 0.1317
# Epoch 119: Average Loss = 0.1391
# Epoch 120: Average Loss = 0.1360
# Epoch 121: Average Loss = 0.1304
# Epoch 122: Average Loss = 0.1348
# Epoch 123: Average Loss = 0.1195
# Epoch 124: Average Loss = 0.1174
# Epoch 125: Average Loss = 0.1211
# Epoch 126: Average Loss = 0.1204
# Epoch 127: Average Loss = 0.1212
# Epoch 128: Average Loss = 0.1285
# Epoch 129: Average Loss = 0.1241
# Epoch 130: Average Loss = 0.1285
# Epoch 131: Average Loss = 0.1255
# Epoch 132: Average Loss = 0.1193
# Epoch 133: Average Loss = 0.1196
# Epoch 134: Average Loss = 0.1248
# Epoch 135: Average Loss = 0.1176
# Epoch 136: Average Loss = 0.1250
# Epoch 137: Average Loss = 0.1233
# Epoch 138: Average Loss = 0.1213
# Epoch 139: Average Loss = 0.1256
# Epoch 140: Average Loss = 0.1360
# Epoch 141: Average Loss = 0.1222
# Epoch 142: Average Loss = 0.1254
# Epoch 143: Average Loss = 0.1252
# Epoch 144: Average Loss = 0.1226
# Epoch 145: Average Loss = 0.1287
# Epoch 146: Average Loss = 0.1242
# Epoch 147: Average Loss = 0.1171
# Epoch 148: Average Loss = 0.1179
# Epoch 149: Average Loss = 0.1235
# Epoch 150: Average Loss = 0.1344
# Epoch 151: Average Loss = 0.1220
# Epoch 152: Average Loss = 0.1149
# Epoch 153: Average Loss = 0.1148
# Epoch 154: Average Loss = 0.1239
# Epoch 155: Average Loss = 0.1219
# Epoch 156: Average Loss = 0.1171
# Epoch 157: Average Loss = 0.1341
# Epoch 158: Average Loss = 0.1194
# Epoch 159: Average Loss = 0.1127
# Epoch 160: Average Loss = 0.1191
# Epoch 161: Average Loss = 0.1328
# Epoch 162: Average Loss = 0.1192
# Epoch 163: Average Loss = 0.1152
# Epoch 164: Average Loss = 0.1305
# Epoch 165: Average Loss = 0.1231
# Epoch 166: Average Loss = 0.1232
# Epoch 167: Average Loss = 0.1248
# Epoch 168: Average Loss = 0.1383
# Epoch 169: Average Loss = 0.1203
# Epoch 170: Average Loss = 0.1153
# Epoch 171: Average Loss = 0.1210
# Epoch 172: Average Loss = 0.1204
# Epoch 173: Average Loss = 0.1244
# Epoch 174: Average Loss = 0.1178
# Epoch 175: Average Loss = 0.1156
# Epoch 176: Average Loss = 0.1110
# Epoch 177: Average Loss = 0.1214
# Epoch 178: Average Loss = 0.1261
# Epoch 179: Average Loss = 0.1184
# Epoch 180: Average Loss = 0.1113
# Epoch 181: Average Loss = 0.1177
# Epoch 182: Average Loss = 0.1125
# Epoch 183: Average Loss = 0.1225
# Epoch 184: Average Loss = 0.1110
# Epoch 185: Average Loss = 0.1129
# Epoch 186: Average Loss = 0.1222
# Epoch 187: Average Loss = 0.1240
# Epoch 188: Average Loss = 0.1230
# Epoch 189: Average Loss = 0.1156
# Epoch 190: Average Loss = 0.1127
# Epoch 191: Average Loss = 0.1148
# Epoch 192: Average Loss = 0.1203
# Epoch 193: Average Loss = 0.1191
# Epoch 194: Average Loss = 0.1285
# Epoch 195: Average Loss = 0.1205
# Epoch 196: Average Loss = 0.1163
# Epoch 197: Average Loss = 0.1123
# Epoch 198: Average Loss = 0.1130
# Epoch 199: Average Loss = 0.1272
# Epoch 200: Average Loss = 0.1246
# Epoch 201: Average Loss = 0.1151
# Epoch 202: Average Loss = 0.1235
# Epoch 203: Average Loss = 0.1121
# Epoch 204: Average Loss = 0.1185
# Epoch 205: Average Loss = 0.1194
# Epoch 206: Average Loss = 0.1240
# Epoch 207: Average Loss = 0.1123
# Epoch 208: Average Loss = 0.1202
# Epoch 209: Average Loss = 0.1174
# Epoch 210: Average Loss = 0.1118
# Epoch 211: Average Loss = 0.1213
# Epoch 212: Average Loss = 0.1271
# Epoch 213: Average Loss = 0.1188
# Epoch 214: Average Loss = 0.1256
# Epoch 215: Average Loss = 0.1310
# Epoch 216: Average Loss = 0.1095
# Epoch 217: Average Loss = 0.1067
# Epoch 218: Average Loss = 0.1556
# Epoch 219: Average Loss = 0.1291
# Epoch 220: Average Loss = 0.1223
# Epoch 221: Average Loss = 0.1215
# Epoch 222: Average Loss = 0.1184
# Epoch 223: Average Loss = 0.1175
# Epoch 224: Average Loss = 0.1216
# Epoch 225: Average Loss = 0.1087
# Epoch 226: Average Loss = 0.1055
# Epoch 227: Average Loss = 0.1065
# Epoch 228: Average Loss = 0.1149
# Epoch 229: Average Loss = 0.1235
# Epoch 230: Average Loss = 0.1141
# Epoch 231: Average Loss = 0.1122
# Epoch 232: Average Loss = 0.1407
# Epoch 233: Average Loss = 0.1125
# Epoch 234: Average Loss = 0.1152
# Epoch 235: Average Loss = 0.1221
# Epoch 236: Average Loss = 0.1143
# Epoch 237: Average Loss = 0.1077
# Epoch 238: Average Loss = 0.1139
# Epoch 239: Average Loss = 0.1106
# Epoch 240: Average Loss = 0.1092
# Epoch 241: Average Loss = 0.1273
# Epoch 242: Average Loss = 0.1224
# Epoch 243: Average Loss = 0.1348
# Epoch 244: Average Loss = 0.1186
# Epoch 245: Average Loss = 0.1090
# Epoch 246: Average Loss = 0.1181
# Epoch 247: Average Loss = 0.1120
# Epoch 248: Average Loss = 0.1157
# Epoch 249: Average Loss = 0.1158
# Epoch 250: Average Loss = 0.1145
# Epoch 251: Average Loss = 0.1080
# Epoch 252: Average Loss = 0.1045
# Epoch 253: Average Loss = 0.1125
# Epoch 254: Average Loss = 0.1158
# Epoch 255: Average Loss = 0.1116

# %%
#Earlier Err rate saturated at 20% -> 12.5% -> (<=11%)
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"  

import matplotlib.pyplot as plt

plt.plot(model.histY, model.histX)
plt.show()

# %%
model.save("AmbSelectorModel.h5")
